# %%
import seaborn as sns
import matplotlib.pyplot as plt


#load dataset

phool = sns.load_dataset("iris")

sns.barplot(x="species",y="petal_length",data=phool)
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#load dataset

kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti)
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#load dataset

kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti, order=["female","male"], color="red")
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#load dataset

kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti, order=["female","male"], color="red", ci= None)
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#load dataset

kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti, order=["female","male"], 
            color="red", ci= None, palette= "pastel")
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
#Estimator
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt


#load dataset

kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="class",y="fare",hue="sex",data=kashti,
            estimator= mean ,ci= None, palette= "pastel", saturation=1)
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
#load dataset horizontal
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt


#load dataset

kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="fare",y="class",hue="sex",data=kashti,
            estimator= mean ,ci= None, saturation=20)
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
#load dataset
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt


#load dataset

kashti = sns.load_dataset("titanic")
kashti
sns.barplot(x="class",y="fare",hue="sex",data=kashti,
            linewidth= 2 , facecolor=(1,1,0.3,1),errcolor="0.1", edgecolor="0")
# plt.title("pholoo ka plot")
# sns.set_style("dark")
plt.show()

# %%
#load dataset
import seaborn
#canvas bALOON

seaborn.set(style="whitegrid")
#load dataset

kashti = seaborn.load_dataset("titanic")

seaborn.boxplot(x='class',y='fare',data=kashti)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
import seaborn
#canvas bALOON

seaborn.set(style="whitegrid")
#load dataset

tip = seaborn.load_dataset("tips")
tip
seaborn.boxplot(x='day',y='tip',data=tip, saturation=1)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn
import numpy
import matplotlib.pyplot as plt
#canvas bALOON

kashti = sns.load_dataset("titanic")
#load dataset

tip = seaborn.load_dataset("tips")
sns.barplot(x="fare",y="class",hue="sex",data=kashti,
            estimator = mean, saturation=1)
# plt.title("pholoo ka plot")
# Out:
# <AxesSubplot:xlabel='fare', ylabel='class'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
#canvas bALOON

seaborn.set(style="whitegrid")
#load dataset

tip = seaborn.load_dataset("tips")
tip.describe()

# seaborn.boxplot(x='day',y='tip',data=tip, saturation=1)
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
seaborn.boxplot(x=tip['size'])
# Out:
# <AxesSubplot:xlabel='size'>

# %%
import seaborn as sns
sns.set(style="darkgrid")
#load dataset

tip = sns.load_dataset("tips")
sns.barplot(x='tip',y='day',hue='smoker',data=tip,color="blue")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>
